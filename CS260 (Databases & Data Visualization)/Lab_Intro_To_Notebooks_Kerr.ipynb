# %% [markdown]
# ### *“Any sufficiently advanced technology is indistinguishable from magic.”*
#
# *–Arthur C. Clarke*
#
# Arthur was a science-fiction writer (he co-wrote the screenplay for the 1968 film *2001: A Space Odyssey*) as well as a science writer, futurist, inventor, undersea explorer, and television series host.
#
# I do hope that after this lab, you find notebooks rather magical!
#
# ---

# %% [markdown]
# # Lab A: Introducing Jupyter Notebooks
# ### Giving credit where credit is due:  Thanks to Data8 for the inital version of this lab!
# ---

# %% [markdown]
# In this lab, you will learn how to navigate a Jupyter Notebook (like this one). Follow the instructions in the notebook to complete the assignment.

# %% [markdown]
# ## Jupyter notebooks
# This webpage is called a Jupyter notebook. A notebook is a place to write programs and view their results.
#
# ## Section A: Text cells
# In a notebook, each rectangle containing text or code is called a *cell*.
#
# Text cells (like this one) can be edited by double-clicking on them.  They're written in a simple format called [Markdown](http://daringfireball.net/projects/markdown/syntax) to add formatting and section headings.  You don't need to learn a lot of Markdown, but some basic Markdown wil help.
#
#
# After you edit a text cell, if you're running in Anaconda, you select the "run cell" button at the top that looks like ▶| to confirm any changes. Otherwise, if working in Colab, just double click on the rendered text that appears to the right.
#
# (Try double clicking on this cell now and then running the cell!)

# %% [markdown]
# ---
# # **Question 1**

# %% [markdown]
# A) This paragraph is in its own text cell.  Try editing it so that **this** sentence is the last sentence in the paragraph. Then run the cell to see the changes.

# %% [markdown]
# B) Double click on the below cell and change your name.

# %% [markdown]
# Your Name: Travis Kerr

# %% [markdown]
# ---
#
# ## Creating Lists in Markdown cells
#
# Like mentioned above, text cells can be formatted with [Markdown](http://daringfireball.net/projects/markdown/syntax).  So for example, I can make words appear in **bold** or in *italics*.  I can also create a list like that below.
#
# MY TO-DO LIST:
# * buy textbooks
# * pack up belongings
# * eat mom's last home-cooked meal
# * drive to college
#
# ## Creating Headers in Markdown cells
#
# Finally, I can create different size headers,  like below.
#
# # Header 1 - Biggest
#
# ## Header 2
#
# ### Header 3
#
# #### Header 4
#
# ##### Header 5
#
# ###### Header 6 - Smallest

# %% [markdown]
# <br/>
# <br/>
# Okay!  Let's get some practice.  Try the question below.

# %% [markdown]
# ---
#
# # **Question 2**
#
# Not sure how to do this problem?  Double clicking on the text cells that you just read above will give you examples of how to complete it!
#
# Bold this word:  **PYTHON**
#
# Italicize this word: *DATA*
#
# ### Make this line appear as Header size 3.
#
# Below create a bulleted list of of your top 3 favorite foods.
#
# MY THREE FAVORITE FOODS:
#
# 1.   Apples
# 2.   Chicken Wings
# 3.   Pizza

# %% [markdown]
# ---
#
# ## Section B: Code Cells
#
# The following cell is not a markdown cell but a code cell.  So we can write code in it.  We will mainly be using Python.  Click on the cell below and run it.  What is printed out?

# %%
#Run this cell!  What is printed out?
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# You just ran your first Python code in Jupyter Notebook.  Now run the following code cell too!

# %%
#Run this cell!  What is printed out?
print("\N{WAVING HAND SIGN}, \N{EARTH GLOBE ASIA-AUSTRALIA}!")
# Out:
# 👋, 🌏!

# %% [markdown]
# The fundamental building block of Python code is an expression. Cells can contain multiple lines with multiple expressions. When you run a cell, the lines of code are executed in the order in which they appear. Every `print` expression prints a line. Run the next cell and notice the order of the output.

# %%
#Run this cell!  What is printed out?
print("First this line is printed,")
print("and then this one.")
# Out:
# First this line is printed,
# and then this one.

# %% [markdown]
# ---
#
# # **Question 3**
#
# Change the cell below so that it prints out:
#
#     First this line,
#     then the whole 🌏,
#     and then this one.
#
# *Hint:* If you're stuck on how to print the Earth symbol, try looking at the print expressions above.
# <br>

# %%
print("First this line is printed,")
print("and then this one.")
# Out:
# First this line is printed,
# and then this one.

# %%
print("First this line,")
print("then the whole \N{EARTH GLOBE ASIA-AUSTRALIA},")
print("and then this one.")
# Out:
# First this line,
# then the whole 🌏,
# and then this one.

# %% [markdown]
# ---
#
# ## Section C: Writing Jupyter notebooks
#
# You can use Jupyter notebooks for your own projects or documents. They are among the world's most popular programming environments for data science. When you make your own notebook, you'll need to create your own cells for text and code.
#
# To add a cell, select the + button in the menu bar.  If you're running on Anaconda and not in Google Colab, then noticed that a new cell starts out as text.  You can change it to a code cell by selecting it so that it's highlighted, then selecting the drop-down box next to the restart (⟳) button in the menu bar and changing the dropdown with "Markdown" to "Code". <br><br>

# %% [markdown]
# ---
#
# # **Question 4**
#
# Add a **code** cell below this one.  Write code in it that prints out:
#
#     A whole new cell!
#     ♪🌏♪
#
# (That musical note symbol is like the Earth symbol.  Its long-form name is `\N{EIGHTH NOTE}`.)
#
# Run your cell to verify that it works.

# %%
print("A whole new cell!") 
print("\N{EIGHTH NOTE}🌏\N{EIGHTH NOTE}")
# Out:
# A whole new cell!
# ♪🌏♪

# %% [markdown]
# ---
# ## Section D: Errors
# Python is a language, and like natural human languages, it has rules.  It differs from natural language in two important ways:
# 1. The rules are *simple*.  You can learn most of them in a few weeks and gain reasonable proficiency with the language in a semester.
# 2. The rules are *rigid*.  If you're proficient in a natural language, you can understand a non-proficient speaker, glossing over small mistakes.  A computer running Python code is not smart enough to do that.
#
# Whenever you write code, you'll make mistakes.  When you run a code cell that has errors, Python will sometimes produce error messages to tell you what you did wrong.
#
# Errors are okay; even experienced programmers make many errors.  When you make an error, you just have to find the source of the problem, fix it, and move on.
#
# We have made an error in the next cell.  Run it and see what happens.

# %%
# Run the cell and see the error!

print("This line is missing something."
# Out:
#   File "<ipython-input-23-425f0bea76c3>", line 3
#     print("This line is missing something."
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# You should see something like this (minus our annotations):
#
# <img src ="https://raw.githubusercontent.com/kathleen-ryan-DeSales/CS250/main/pictures/LabA_error.jpg" alt="MISSING"/>
#
# The last line of the error output attempts to tell you what went wrong.  The *syntax* of a language is its structure, and this `SyntaxError` tells you that you have created an illegal structure.  "`EOF`" means "end of file," so the message is saying Python expected you to write something more (in this case, a right parenthesis) before finishing the cell.
#
# There's a lot of terminology in programming languages. You'll learn as you go. If you are ever having trouble understanding an error message, search the discussion forum. If you don't find an answer, post a question about the error yourself.

# %% [markdown]
# ---
#
# # **Question 5**
#
# Try to fix the code above so that you can run the cell and see the intended message instead of an error.
#
# ---

# %%
print("This line is missing something.")
# Out:
# This line is missing something.

# %% [markdown]
# ## Section E: So what is a Jupyter Notebook, really?

# %% [markdown]
# A Jupyter Notebook is a file/notebook that can contain both code and regular text (like this paragraph here!) as well as math formulas, images, links, and more. The fact that a Jupyter Notebook can contains all of these various elements makes it a valuable tool for people, especially when doing data analysis, since the analysis description and the results can be contained in the same document.
#
# Every notebook has something called a **kernel**, which acts as the operation part of the notebook. With the kernel, we can execute the lines of code that are in a notebook. When you open a notebook, the kernel associated with that notebook is automatically launched as well. When we execute or run a notebook, the kernel performs the computations and then returns the results.  If you're using Google Colab, this kernel runs on a computer provided to us by Google.  Otherwise, if you're using Anaconda, then the kernel is running locally on your physical machine.

# %% [markdown]
# ## Section F: Shortcut keys
#
# There are a LOT of short cut keys we can use.  Here are a few that I use the most.

# %% [markdown]
# With shortcut keys, you can easily add cells above/below the one you are working in.  Here's how.
#
# If working in Jupyter notebook:
# * Press ```Escape + b``` to insert a cell below the one you are working in.
# * Press ```Escape + a``` to insert a cell below the one you are working in.
#
# If working in Google Colab, the above codes will work, but usually you will use ctrl for shortcut keys. So instead try this:
# * Press ```ctrl + b``` to insert a cell below the one you are working in.
# * Press ```ctrl + a``` to insert a cell below the one you are working in.
#
# <br><br>

# %% [markdown]
# ---
#
# # **Question 6**

# %%
print("ABOVE")
# Out:
# ABOVE

# %% [markdown]
# Double click on this cell and then use the short cut just describe to add two **CODE** cells:
#
# * One above. By default, it will be a code cell.  In it, print out the phrase "ABOVE"
# * One below. Again, it will be a code cell.  In it, print out the phrase "BELOW"

# %%
print("BELOW")
# Out:
# BELOW

# %% [markdown]
# ---

# %% [markdown]
# <br><br>Since new cells are by default code cells, it's nice to know the shortcut for how to change them to markdown cells.
#
# If you are using Jupyter Notebooks:
# * ```Escape + m``` changes the cell to a markdown cell
# * ```Escape + y``` changes the cell to a code cell
#
# If you are using Google Colab:
# * ```Ctrl + m + m``` changes the cell to a markdown cell
# * ```Ctrl + m + y``` changes the cell to a code cell
# <br><br>

# %% [markdown]
# ---
#
# # **Question 7**
#
# Add a cell below this one and change it to a markdown cell. Use the shortcuts you have learned to do this!  In the cell, write this:  "Shortcut keys are awesome!"  Because this is a markdown cell, you will NOT use the Python ```print``` command to show the desired prhase.

# %% [markdown]
# "Shortcut keys are awesome!"

# %% [markdown]
# ---

# %% [markdown]
# <br><br>
# Finally, deleting a cell can be helpful.
#
# To do this in Jupyter notebooksm, type ```Escape + d + d``` (so escape and then the letter d twice).
#
# To do this in Google Colan,  type ```ctrl + m + d```.
#
# <br>

# %% [markdown]
# ---
#
# # **Question 8**
#
# Delete the cell below. Use the shortcuts you have learned to do this!
# ---

# %% [markdown]
# ---
#
# ## Section G: A good thing to do before submitting
#
# Sometimes students skip questions and forget to go back to them.  Watch the video below to help you not do this.
#
# * [How to use the table of contents](https://desales.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=09d83ef3-8504-4c25-814f-aef9012b128e)  (If asked to log in, use your Blackboard credentials.)
#
# ---
#
# <br/>
#
# Okay!  You're done!  Submit this!  Be sure to rename it if my Blackboard instructions say to do so. </span>
