# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
x = 40

3 * x

2 * x
# Out:
# 80

# %% [markdown]
# I can type anything here and it won't crash

# %%
print("I can't type anything here")
# Out:
# I can't type anything here

# %% [markdown]
# ### This is a header
# Let's bold this word: **Yay DSU!**
